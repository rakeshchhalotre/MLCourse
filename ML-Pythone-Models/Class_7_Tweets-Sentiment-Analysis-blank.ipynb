# %%
# !pip install tweepy
#!pip install textblob

# %%
import re # regular expression / regex
import tweepy #Collect tweets
from tweepy import OAuthHandler # Authentication
from textblob import TextBlob # provides text mining, text analysis and text processing modules

# %%
querytext = "Tsunami" #any keyword

# %%
class TwitterClient(object):
    '''
    Generic Twitter Class for sentiment analysis.
    '''
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'ts8RhO1B1qIzdSLaDsaise89a'
        consumer_secret = 'A4ZawHMrKiAaoxfQhmjrW5F2gWwgjh9jhCuvczy8cymLaTJfES'
        access_token = '929606650415136768-Ok0ca8lkQk7oD8xNUqKWKg9VyoEXJRV'
        access_token_secret = '5mJm07yiPpvFB7M4Z9l4yaip4k6gvSpL2mEMMs6sEXjqX'
 
        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print("Error: Authentication Failed")
 
    def clean_tweet(self, tweet):
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("/@%&", " ", tweet).split())
 
    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
 
    def get_tweets(self, query, count = 10):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
 
        try:
            # call twitter api to fetch tweets
            fetched_tweets = self.api.search(q = query, count = count)
 
            # parsing tweets one by one
            for tweet in fetched_tweets:
                # empty dictionary to store required params of a tweet
                parsed_tweet = {}
 
                # saving text of tweet
                parsed_tweet['text'] = tweet.text
                # saving sentiment of tweet
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
 
                # appending parsed tweet to tweets list
                if tweet.retweet_count > 0:
                    # if tweet has retweets, ensure that it is appended only once
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                else:
                    tweets.append(parsed_tweet)
 
            # return parsed tweets
            return tweets
 
        except tweepy.TweepError as e:
            # print error (if any)
            print("Error : " + str(e))

# %%
querytext = 'modi'
def main():
    # creating object of TwitterClient Class
    api = TwitterClient()
    # calling function to get tweets
    tweets = api.get_tweets(query = querytext, count = 1000)
    print("Queries Text : ", querytext)
    # picking positive tweets from tweets
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
    # percentage of positive tweets
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
    # picking negative tweets from tweets
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
    # percentage of negative tweets
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
    # percentage of neutral tweets
    print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))
    print("\n\n Total Tweets:",len(tweets))
    # printing first 5 positive tweets
    print("\n\nPositive tweets:")
    for tweet in ptweets[:10]:
        print(tweet['text'])
 
    # printing first 5 negative tweets
    print("\n\nNegative tweets:")
    for tweet in ntweets[:15]:
        print(tweet['text'])

# %%
querytext = 'rahul gandhi'
main()
# Out:
# Queries Text :  rahul gandhi
# Positive tweets percentage: 27.906976744186046 %
# Negative tweets percentage: 6.976744186046512 %
# Neutral tweets percentage: 65.11627906976744 %
#
#
#  Total Tweets: 43
#
#
# Positive tweets:
# RT @Babu_Bhaiyaa: Film #AccidentalPrimeMinister is banned in many Congress ruled sates. Sadly Entertainment is new victim of Politics. BJP…
# RT @AunindyoC: 4) MMS successfully blocked some of the key 10 Janpath schemes. Along with P Chidambaram, he lowered outlay to MGNREGA and o…
# RT @OpIndia_com: Anupam Kher said that Dr Manmohan Singh will love the movie, and appreciate his work
# https://t.co/4tfZgoGJJY
# RT @IndiaToday: Rahul Gandhi has managed to give BJP and RSS an effective challenge in their own entrenched states: @priyankac19
# #Newsmaker…
# RT @IndiaToday: #NewsmakerRahulGandhi
# Under @RahulGandhi's leadership, @INCIndia has made a remarkable turnaround in just one year.
# https:…
# RT @AsYouNotWish: As someone who’s been taught to respect elders, it really breaks my heart to see how Rahul Gandhi serves that piece of ca…
# India Today should go talk to people before making such assertion. Most of people laugh at Rahul Gandhi and have de… https://t.co/zWhX2nDLlj
# RT @IndiaToday: Rahul Gandhi emerges as the #Newsmaker2018. Watch what kept him in the news throughout the year.
# Live https://t.co/4fqxBV…
# RT @rajneilkamath: "This was in 2013 when Rahul was Congress general secretary and new to politics"
#
# @_pallavighosh, in 2013, Rahul was new…
# RT @ashoswai: Two years back I had written that Rahul Gandhi would be Justin Trudeau of India. Many had laughed then, but no one dares to t…
#
#
# Negative tweets:
# RT @rose_k01: If a movie were to be made on Rahul Gandhi what would be its title? 🤔
#
# I say: The LYING IDIOT
#
# Feel free to drop your suggest…
# RT @KarunaGopal1: Which one is a bigger joke ??
# Rahul Gandhi talking about why snooping on people is bad
# Or
# Imran Khan talking about ways…
# RT @barbarindian: Nandita Das, daughter of serial perv artist Jatin Das made a dangerous propaganda movie called Firaaq with cringe inducin…
